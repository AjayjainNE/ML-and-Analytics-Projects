# %% [markdown]
# <h2>Getting Started with your Lab Sandbox</h2>
# <p>You can find important course-specific tips and notes for your Lab Sandbox in this <br>
#     quick guide to use throughout your course. You’ll be able to reference this at any time <br>
#     or visit the <a href="https://learner.coursera.help/hc/articles/360062301971">Learner Help Center</a>
#     for more info. </p>
#
# <h2>What tools are already installed in my sandbox environment?</h2>
# <ul>
#   <li>Python==3.7.6</li>
#   <li>scikit-learn(same as sklearn)==0.22.2.post1</li>
#   <li>pandas==1.0.3</li>
#   <li>numpy==1.18.4</li>
#   <li>matplotlib==3.2.1</li>
#   <li>pydotplus</li>
#   <li>graphviz</li>
# </ul>
#
# <h2>Additional Course Specific Notes:</h2>
#
# <ul>
#    <li>Please note that this Lab Sandbox supports <b>Python Jupyter Notebooks</b> to help you complete <br>
#         you assignments. SAS is also mentioned in the course as another tool option, but <br>
#         SAS will not be supported in this Sandbox. Don't worry - you'll still be able to <br> complete your required work using these Jupyter Notebooks. You can learn more <a href="https://www.coursera.org/learn/machine-learning-data-analysis/supplement/HpcYx/getting-started-with-python">in this reading.</a><br></li><br>
#     <li>To run python scripts from Jupyter Notebooks, you can upload your .py file <br>
#         to the Jupyter File tree using the "Upload" option. You can then either run your Python file <br>
#         from the Terminal or from your Jupyter Notebook using the following syntax: <br>
#         - <b>Terminal:</b> "python3 [your_script_name].py"</li>
#         - <b>Jupyter Code Cell:</b> "%run -i [your_script_name].py"</li><br><br>
#     <li>Throughout this course, you'll encounter datasets which are hosted on other websites. <br>
#         If you'd like to complete your work in the lab sandbox environment, please download these <br>
#         datasets from their listed websites and upload the data files directly into your Jupyter Sandbox <br>
#         environment. Lab Sandboxes have limited access to external sites, so uploading your data files<br>
#         directly will help ensure you do not hit any access errors. You can upload zipped data by either:<br>
#         1) Unzipping files locally and uploading them to your Sandbox <br>
#         2) Uploading your zip file and unzipping files via the New -> Terminal Jupyter tool</li><br>
#     <li><b>IMPORTANT: To optimize your notebook performance, please shut down each of your <br>
#         open/running Jupyter Notebooks after you complete them within your Lab</b>. <br>
#         This will provide full and dedicated system resources to the current lab assignment<br>
#         you are working on in your Lab Sandbox. If you experience any unexpected slow <br>
#         processing in your notebook, try to restart your Lab kernel and only open that single <br>
#         notebook to complete your work. You can learn more about restarting your Lab Sandbox <br>
#         and troubleshooting your lab in our Learner Help Center article <a href="https://learner.coursera.help/hc/articles/360044758731-Solving-Common-Issues-with-Coursera-Labs">here</a>.</li><br>
#     <li>Use mse_path_ instead of cv_ms_path. Use sklearn.model_select in import train_test_split<br>
#     instead of from sklearn.cross_validation import train_test_split</li><br>
#     <li>If anything is unclear regarding the course content, please go through the <br>
#         Discussion board and see if your question has been answered. If you have any issues <br>
#         with the Jupyter environment itself, please contact Coursera through the <a href="https://learner.coursera.help">Learner Help Center.</a></li><br>
# </ul>
